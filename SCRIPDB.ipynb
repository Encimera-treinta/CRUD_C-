-- %% [markdown]
-- # [Horarios_Academicos]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Horarios_Academicos]    Script Date: 07/28/2025 4:06:22 p. m. ******/
CREATE DATABASE [Horarios_Academicos]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'HorariosAcademicos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HorariosAcademicos.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'HorariosAcademicos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\HorariosAcademicos_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Horarios_Academicos] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Horarios_Academicos].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Horarios_Academicos] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET ARITHABORT OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Horarios_Academicos] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Horarios_Academicos] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Horarios_Academicos] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Horarios_Academicos] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Horarios_Academicos] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Horarios_Academicos] SET  MULTI_USER 
GO
ALTER DATABASE [Horarios_Academicos] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Horarios_Academicos] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Horarios_Academicos] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Horarios_Academicos] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Horarios_Academicos] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Horarios_Academicos] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Horarios_Academicos] SET QUERY_STORE = ON
GO
ALTER DATABASE [Horarios_Academicos] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [Encimera-treinta30]

-- %%
USE [Horarios_Academicos]
GO

-- %%
/****** Object:  User [Encimera-treinta30]    Script Date: 07/28/2025 4:06:23 p. m. ******/
CREATE USER [Encimera-treinta30] FOR LOGIN [Encimera-treinta30] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [an]

-- %%
/****** Object:  User [an]    Script Date: 07/28/2025 4:06:23 p. m. ******/
CREATE USER [an] FOR LOGIN [an] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[cursos]

-- %%
/****** Object:  Table [dbo].[cursos]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cursos](
	[cursoid] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[profesorid] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[cursoid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[horarios]

-- %%
/****** Object:  Table [dbo].[horarios]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[horarios](
	[horarioid] [int] IDENTITY(1,1) NOT NULL,
	[dia] [varchar](20) NULL,
	[horainicio] [time](7) NULL,
	[horafin] [time](7) NULL,
	[cursoid] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[horarioid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[profesor]

-- %%
/****** Object:  Table [dbo].[profesor]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[profesor](
	[profesorid] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[especialidad] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[profesorid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__cursos__profesor__4BAC3F29]

-- %%
ALTER TABLE [dbo].[cursos]  WITH CHECK ADD FOREIGN KEY([profesorid])
REFERENCES [dbo].[profesor] ([profesorid])
GO

-- %% [markdown]
-- # [FK__horarios__cursoi__4E88ABD4]

-- %%
ALTER TABLE [dbo].[horarios]  WITH CHECK ADD FOREIGN KEY([cursoid])
REFERENCES [dbo].[cursos] ([cursoid])
GO

-- %% [markdown]
-- # [dbo].[ActualizarCurso]

-- %%
/****** Object:  StoredProcedure [dbo].[ActualizarCurso]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActualizarCurso]
    @cursoid INT,
    @nombre VARCHAR(100),
    @profesorid INT
AS
BEGIN
    UPDATE cursos
    SET nombre = @nombre,
        profesorid = @profesorid
    WHERE cursoid = @cursoid;
END;
GO

-- %% [markdown]
-- # [dbo].[ActualizarHorario]

-- %%
/****** Object:  StoredProcedure [dbo].[ActualizarHorario]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActualizarHorario]
    @horarioid INT,
    @dia VARCHAR(20),
    @horainicio TIME,
    @horafin TIME,
    @cursoid INT
AS
BEGIN
    UPDATE horarios
    SET dia = @dia,
        horainicio = @horainicio,
        horafin = @horafin,
        cursoid = @cursoid
    WHERE horarioid = @horarioid;
END;
GO

-- %% [markdown]
-- # [dbo].[ActualizarProfesor]

-- %%
/****** Object:  StoredProcedure [dbo].[ActualizarProfesor]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActualizarProfesor]
    @profesorid INT,
    @nombre VARCHAR(100),
    @especialidad VARCHAR(100)
AS
BEGIN
    UPDATE profesor
    SET nombre = @nombre,
        especialidad = @especialidad
    WHERE profesorid = @profesorid;
END;
GO

-- %% [markdown]
-- # [dbo].[EliminarCurso]

-- %%
/****** Object:  StoredProcedure [dbo].[EliminarCurso]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[EliminarCurso]
    @cursoid INT
AS
BEGIN
    DELETE FROM cursos
    WHERE cursoid = @cursoid;
END;
GO

-- %% [markdown]
-- # [dbo].[EliminarHorario]

-- %%
/****** Object:  StoredProcedure [dbo].[EliminarHorario]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[EliminarHorario]
    @horarioid INT
AS
BEGIN
    DELETE FROM horarios
    WHERE horarioid = @horarioid;
END;
GO

-- %% [markdown]
-- # [dbo].[EliminarProfesor]

-- %%
/****** Object:  StoredProcedure [dbo].[EliminarProfesor]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[EliminarProfesor]
    @profesorid INT
AS
BEGIN
    DELETE FROM profesor
    WHERE profesorid = @profesorid;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertarCurso]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertarCurso]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertarCurso]
    @nombre VARCHAR(100),
    @profesorid INT
AS
BEGIN
    INSERT INTO cursos (nombre, profesorid)
    VALUES (@nombre, @profesorid);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertarHorario]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertarHorario]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertarHorario]
    @dia VARCHAR(20),
    @horainicio TIME,
    @horafin TIME,
    @cursoid INT
AS
BEGIN
    INSERT INTO horarios (dia, horainicio, horafin, cursoid)
    VALUES (@dia, @horainicio, @horafin, @cursoid);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertarProfesor]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertarProfesor]    Script Date: 07/28/2025 4:06:23 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertarProfesor]
    @nombre VARCHAR(100),
    @especialidad VARCHAR(100)
AS
BEGIN
    INSERT INTO profesor (nombre, especialidad)
    VALUES (@nombre, @especialidad);
END;
GO

-- %% [markdown]
-- # [Horarios_Academicos]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Horarios_Academicos] SET  READ_WRITE 
GO
